# %% [markdown]
# ### Exercitiul 5 ###

# %% [markdown]
# | Numărul de respondenți | Genul de muzică |
# | ---------------------- | --------------- |
# | 200 | clasică |
# | 171 | jazz |
# | 311 | blues |
# | 411 | rock |
# | 401 | electronică |
# | 355 | folk |

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.close("all")

x = [200, 171, 311, 411, 401, 355]
dataName = ['clasica', 'jazz', 'blues', 'rock', 'electronica', 'folk']

plt.figure(figsize=(6,8))
plt.pie(x, labels=dataName)
plt.legend()

plt.show()
